# %%
# %matplotlib notebook

import numpy as np
import cv2
import os
import sys

sys.path.append('../functions/')
sys.path.append('../utils/')

from DoG import DoG
from file_manager import File_manager
from wdd_decoder_functions import create_diff_images, calculate_image_sum_for_frame, calculate_image_sum_for_angle


from matplotlib import pyplot as plt
from joblib import Parallel, delayed
from sklearn.linear_model import TheilSenRegressor
from skimage.transform import radon, rescale

from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import multivariate_normal

import pandas as pd

# %%
# %load_ext line_profiler

# %%
radi = np.pi / 180
cov_matrix = np.matrix([[6., 0],[0, 2.]])

smothing = np.matrix([[1,1,1],[1,1,1],[1,1,1]]) / 9

path = '/home/sascwitt/Projects/test/WDs/'
folders = os.listdir(path)
folders.sort()

# %%
dog = DoG().mexican_head_kernel

cov1 = 30 * np.eye(2)
cov2 = 4 * np.eye(2)

_dog = abs(np.fft.fftshift(np.fft.fft2(dog(50, [25,25], cov1, [25,25], cov2))))

plt.figure()
plt.imshow(_dog, cmap=plt.cm.jet)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
fm_csv = File_manager("/home/sascwitt/Projects/test/WDs/").read_csv

# %%
diff_img = create_diff_images(path, folders)

# %%
fft_imgs = []
keys = []

for key, img_arrays in list(diff_img.items()):
    keys.append(key)
    image = None
    
    for img in img_arrays:
        tmp = np.fft.fftshift(abs(np.fft.fft2(img)))
        if image is None:
            image = tmp
        
        else:
            image += tmp
    
    fft_imgs.append(image)

# %%
plt.figure()
plt.imshow(fft_imgs[0], cmap=plt.cm.jet)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.imshow(np.power(np.multiply(fft_imgs[0], _dog), 5), cmap=plt.cm.jet)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.imshow(np.multiply(fft_imgs[0], _dog), cmap=plt.cm.jet)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
def img_moments(image, p, q):
    height, width = image.shape
    center_x = width / 2
    center_y = height / 2
    
    x = np.arange(0, width)
    y = np.arange(0, height)

    X = np.power((x - center_x), p)[np.newaxis]
    Y = np.power((y - center_y), q)[np.newaxis]
    
    t1 = X * Y.T
    
    return sum(sum(np.multiply(t1, image)))

# %%
def get_img_cov(image):
    m00 = img_moments(image, 0, 0)
    m11_ = img_moments(image, 1, 1) / m00
    m02_ = img_moments(image, 0, 2) / m00
    m20_ = img_moments(image, 2, 0) / m00
    
    img_cov = np.array([[m20_, m11_], [m11_,m02_]])

    return img_cov

# %%
def translate_coordinates(coordinates, image):
    image_center = image.shape
    
    sum_x = 0
    sum_y = 0
    
    count_x = 0
    count_y = 0
    
    for i in range(len(coordinates)):
        if (i % 2 == 0):
            sum_x += i
            count_x += 1
        else:
            sum_y += i
            count_y += 1
            
    print(coordinates[0], coordinates[1])
    print(coordinates[-2], coordinates[-1])
    print(len(coordinates))
    print(count_x, count_y)
    print(sum_x, sum_y)
    mean_x = sum_x / count_x
    mean_y = sum_y / count_y
    print(mean_x, mean_y)
    x_one = (coordinates[0] - mean_x) + image_center[0]
    x_two = (coordinates[-2] - mean_x) + image_center[0] 
    
    y_one = (coordinates[1] - mean_y) + image_center[1]
    y_two = (coordinates[-1] - mean_y) + image_center[1]
    
    line = np.array([[x_one, y_one], [x_two, y_two]])
    print(line)

# %%
error = []
ct = 0
cf = 0

for index, image in enumerate(fft_imgs):
    dog_filtered = np.multiply(image, _dog)
    
    powered_dog = np.power(dog_filtered, 5)
    
    img_cov = get_img_cov(powered_dog)
    
    w, v = np.linalg.eig(img_cov)
    eig_v_min = np.array([v[np.argmin(w)][1], v[np.argmin(w)][0]])
    
    calc_angle = np.arctan2(eig_v_min[0], eig_v_min[1])/radi
    
    split_keys = keys[index].split("/")
    
    test = fm_csv(keys[index] + split_keys[-3] + "_" + split_keys[-2] + '.csv')
    test = np.array(list(test.values())[0].split(" "))[:-1].astype(float)
    
    dir_vec = np.array([test[-2] - test[0], test[-1] - test[1]])
    
    translate_coordinates(test, image)

#     print(test[0], line)
    
    
    direction = eig_v_min.T @ dir_vec * eig_v_min
    
    gt_angle = float(fm_csv(keys[index] + "result.csv")["Angle"])
    
    t = dir_vec[0] - dir_vec[1]
    
    print(gt_angle)
    #print(img_cov)
    
    dir_bool = False
    gt_dir = False
    
    if (gt_angle == - 0.0):
        gt_angle = 0.0
        
    
    if (gt_angle >= 0):
        gt_dir = True
    
    if (t >= 0):
        dir_bool = True
    
    if(dir_bool == gt_dir):
        ct += 1
    else:
#         print(t, gt_angle, index)
        cf += 1
    #gt_angle = float(fm_csv(keys[index] + "result.csv")["Angle"])
    
    error.append(calc_angle - gt_angle)
# Out:
# 111.6 79.6
# 117.8 78.3
# 130
# 65 65
# 4160 4225
# [[  97.6   64.6]
#  [ 103.8   63.3]]
# 9.16234704572
# 78.1 106.3
# 78.2 110.7
# 162
# 81 81
# 6480 6561
# [[ 48.1  75.3]
#  [ 48.2  79.7]]
# -93.6329507395
# 103.3 66.6
# 105.3 67.8
# 104
# 52 52
# 2652 2704
# [[ 102.3   64.6]
#  [ 104.3   65.8]]
# -0.0
# 103.2 88.6
# 106.5 88.7
# 122
# 61 61
# 3660 3721
# [[ 93.2  77.6]
#  [ 96.5  77.7]]
# 41.3915311474
# 80.3 109.0
# 78.4 114.8
# 122
# 61 61
# 3660 3721
# [[  70.3   98. ]
#  [  68.4  103.8]]
# -134.492970939
# 84.9 61.4
# 83.8 64.8
# 126
# 63 63
# 3906 3969
# [[ 72.9  48.4]
#  [ 71.8  51.8]]
# -94.08561678
# 78.7 72.8
# 82.5 71.0
# 124
# 62 62
# 3782 3844
# [[ 67.7  60.8]
#  [ 71.5  59. ]]
# -0.0
# 107.0 52.3
# 107.8 53.0
# 90
# 45 45
# 1980 2025
# [[ 113.    57.3]
#  [ 113.8   58. ]]
# 17.4747742563
# 105.0 62.6
# 108.8 61.0
# 104
# 52 52
# 2652 2704
# [[ 104.    60.6]
#  [ 107.8   59. ]]
# 18.7586503478
# 105.6 83.8
# 109.5 82.5
# 130
# 65 65
# 4160 4225
# [[ 91.6  68.8]
#  [ 95.5  67.5]]
# 44.3969088056
# 87.3 63.3
# 84.4 66.3
# 106
# 53 53
# 2756 2809
# [[ 85.3  60.3]
#  [ 82.4  63.3]]
# -146.023455964
# 84.9 108.4
# 88.0 107.3
# 146
# 73 73
# 5256 5329
# [[ 62.9  85.4]
#  [ 66.   84.3]]
# 13.2405199152
# 94.9 62.7
# 90.8 67.8
# 172
# 86 86
# 7310 7396
# [[ 59.9  26.7]
#  [ 55.8  31.8]]
# -129.805571092
# 104.0 67.0
# 106.2 67.3
# 130
# 65 65
# 4160 4225
# [[ 90.   52. ]
#  [ 92.2  52.3]]
# 18.7413404452
# 103.5 57.8
# 105.7 56.7
# 106
# 53 53
# 2756 2809
# [[ 101.5   54.8]
#  [ 103.7   53.7]]
# -1.81830296445
# 67.5 66.7
# 61.8 69.0
# 66
# 33 33
# 1056 1089
# [[ 85.5  83.7]
#  [ 79.8  86. ]]
# -120.963756532
# 98.5 115.3
# 96.5 116.3
# 88
# 44 44
# 1892 1936
# [[ 105.5  121.3]
#  [ 103.5  122.3]]
# -9.09027692082
# 113.8 90.0
# 113.0 90.4
# 50
# 25 25
# 600 625
# [[ 139.8  115. ]
#  [ 139.   115.4]]
# 9.03948280336
# 96.3 113.5
# 100.7 113.3
# 68
# 34 34
# 1122 1156
# [[ 113.3  129.5]
#  [ 117.7  129.3]]
# -2.81555668421
# 100.3 49.0
# 95.8 53.0
# 128
# 64 64
# 4032 4096
# [[ 87.3  35. ]
#  [ 82.8  39. ]]
# -133.958373324
# 74.3 113.3
# 75.3 110.3
# 82
# 41 41
# 1640 1681
# [[  84.3  122.3]
#  [  85.3  119.3]]
# 24.5671713206
# 82.5 68.8
# 77.5 71.0
# 100
# 50 50
# 2450 2500
# [[ 83.5  68.8]
#  [ 78.5  71. ]]
# -113.198590514
# 79.2 59.6
# 82.7 58.7
# 72
# 36 36
# 1260 1296
# [[ 94.2  73.6]
#  [ 97.7  72.7]]
# -34.6951535312
# 62.3 81.8
# 63.0 83.4
# 82
# 41 41
# 1640 1681
# [[ 72.3  90.8]
#  [ 73.   92.4]]
# -56.5921754103
# 108.3 77.2
# 109.0 79.8
# 86
# 43 43
# 1806 1849
# [[ 116.3   84.2]
#  [ 117.    86.8]]
# 17.1027289691
# 104.3 64.5
# 108.8 63.5
# 114
# 57 57
# 3192 3249
# [[  98.3   57.5]
#  [ 102.8   56.5]]
# 25.0168934781
# 91.0 68.8
# 95.8 70.2
# 102
# 51 51
# 2550 2601
# [[ 91.   67.8]
#  [ 95.8  69.2]]
# 2.72631099391
# 107.8 85.7
# 109.8 85.0
# 128
# 64 64
# 4032 4096
# [[ 94.8  71.7]
#  [ 96.8  71. ]]
# 13.4957332808
# 112.3 91.0
# 115.8 91.1
# 82
# 41 41
# 1640 1681
# [[ 122.3  100. ]
#  [ 125.8  100.1]]
# -0.84252426074
# 96.7 50.8
# 97.8 54.3
# 84
# 42 42
# 1722 1764
# [[ 105.7   58.8]
#  [ 106.8   62.3]]
# -113.198590514
# 102.3 71.5
# 107.4 69.2
# 86
# 43 43
# 1806 1849
# [[ 110.3   78.5]
#  [ 115.4   76.2]]
# 26.2413496522
# 89.5 82.3
# 90.8 80.2
# 112
# 56 56
# 3080 3136
# [[ 84.5  76.3]
#  [ 85.8  74.2]]
# 33.9435870198
# 87.8 64.3
# 87.3 67.4
# 74
# 37 37
# 1332 1369
# [[ 101.8   77.3]
#  [ 101.3   80.4]]
# -126.027373385
# 84.0 73.0
# 89.0 71.7
# 100
# 50 50
# 2450 2500
# [[ 85.   73. ]
#  [ 90.   71.7]]
# 13.4310288707
# 113.5 79.2
# 116.0 81.3
# 88
# 44 44
# 1892 1936
# [[ 120.5   85.2]
#  [ 123.    87.3]]
# 13.0693178963
# 70.6 67.4
# 72.2 72.6
# 120
# 60 60
# 3540 3600
# [[ 61.6  57.4]
#  [ 63.2  62.6]]
# 6.24191434742
# 109.5 69.8
# 109.5 68.2
# 88
# 44 44
# 1892 1936
# [[ 116.5   75.8]
#  [ 116.5   74.2]]
# 14.5344550805
# 111.0 78.5
# 113.2 78.0
# 118
# 59 59
# 3422 3481
# [[ 103.    69.5]
#  [ 105.2   69. ]]
# 16.9275130641
# 111.2 84.6
# 113.0 83.3
# 56
# 28 28
# 756 784
# [[ 134.2  106.6]
#  [ 136.   105.3]]
# 14.9950791292
# 78.8 51.4
# 79.7 51.8
# 46
# 23 23
# 506 529
# [[ 106.8   78.4]
#  [ 107.7   78.8]]
# -146.611486424
# 109.0 81.5
# 110.0 82.5
# 150
# 75 75
# 5550 5625
# [[ 85.   56.5]
#  [ 86.   57.5]]
# 13.799485396
# 86.8 70.5
# 83.6 74.4
# 164
# 82 82
# 6642 6724
# [[ 55.8  38.5]
#  [ 52.6  42.4]]
# -126.027373385
# 101.5 87.5
# 107.4 86.2
# 160
# 80 80
# 6320 6400
# [[ 72.5  57.5]
#  [ 78.4  56.2]]
# 31.5042667192
# 101.0 85.5
# 107.4 86.2
# 152
# 76 76
# 5700 5776
# [[ 76.   59.5]
#  [ 82.4  60.2]]
# 21.3368592918
# 83.8 70.8
# 81.9 75.8
# 120
# 60 60
# 3540 3600
# [[ 74.8  60.8]
#  [ 72.9  65.8]]
# -109.384515679
# 102.5 84.5
# 107.4 86.2
# 144
# 72 72
# 5112 5184
# [[ 81.5  62.5]
#  [ 86.4  64.2]]
# 21.4767909795
# 82.8 63.8
# 80.4 67.1
# 80
# 40 40
# 1560 1600
# [[ 93.8  73.8]
#  [ 91.4  77.1]]
# -134.215175397
# 101.7 85.6
# 103.8 83.3
# 98
# 49 49
# 2352 2401
# [[ 103.7   86.6]
#  [ 105.8   84.3]]
# 30.3236068625
# 83.4 72.2
# 85.8 71.0
# 146
# 73 73
# 5256 5329
# [[ 61.4  49.2]
#  [ 63.8  48. ]]
# 20.6589100633
# 99.8 75.5
# 106.0 70.6
# 164
# 82 82
# 6642 6724
# [[ 68.8  43.5]
#  [ 75.   38.6]]
# 20.2248594312
# 66.5 91.3
# 61.6 93.0
# 136
# 68 68
# 4556 4624
# [[ 49.5  73.3]
#  [ 44.6  75. ]]
# -121.429565615
# 116.7 106.5
# 117.8 107.1
# 54
# 27 27
# 702 729
# [[ 140.7  129.5]
#  [ 141.8  130.1]]
# -6.22582906443
# 103.4 82.8
# 105.6 82.2
# 104
# 52 52
# 2652 2704
# [[ 102.4   80.8]
#  [ 104.6   80.2]]
# 20.6589100633
# 100.0 60.8
# 95.3 64.3
# 104
# 52 52
# 2652 2704
# [[ 99.   58.8]
#  [ 94.3  62.3]]
# -156.124719146
# 77.2 75.0
# 75.5 76.5
# 50
# 25 25
# 600 625
# [[ 103.2  100. ]
#  [ 101.5  101.5]]
# -147.587693382
# 110.0 85.2
# 114.5 85.3
# 148
# 74 74
# 5402 5476
# [[ 87.   61.2]
#  [ 91.5  61.3]]
# 42.8789036033
# 100.0 63.8
# 103.8 62.0
# 88
# 44 44
# 1892 1936
# [[ 107.    69.8]
#  [ 110.8   68. ]]
# 16.5348378573
# 84.8 102.5
# 88.8 98.0
# 208
# 104 104
# 10712 10816
# [[ 31.8  48.5]
#  [ 35.8  44. ]]
# 22.2490236572
# 110.0 74.8
# 115.5 73.3
# 120
# 60 60
# 3540 3600
# [[ 101.    64.8]
#  [ 106.5   63.3]]
# 33.690067526
# 86.9 68.0
# 85.0 70.0
# 88
# 44 44
# 1892 1936
# [[ 93.9  74. ]
#  [ 92.   76. ]]
# -127.694240467
# 89.0 62.5
# 86.3 68.3
# 140
# 70 70
# 4830 4900
# [[ 70.   42.5]
#  [ 67.3  48.3]]
# -94.2363947991
# 90.0 108.8
# 91.7 108.6
# 54
# 27 27
# 702 729
# [[ 114.   131.8]
#  [ 115.7  131.6]]
# -18.6989828042
# 77.6 106.0
# 77.0 109.0
# 86
# 43 43
# 1806 1849
# [[  85.6  113. ]
#  [  85.   116. ]]
# -118.300755766
# 94.3 68.8
# 97.0 67.8
# 82
# 41 41
# 1640 1681
# [[ 104.3   77.8]
#  [ 107.    76.8]]
# 32.5350671579
# 105.9 85.9
# 109.8 85.0
# 124
# 62 62
# 3782 3844
# [[ 94.9  73.9]
#  [ 98.8  73. ]]
# 17.5712587783
# 103.4 86.5
# 105.0 83.5
# 112
# 56 56
# 3080 3136
# [[  98.4   80.5]
#  [ 100.    77.5]]
# 16.2940474566
# 83.4 72.2
# 85.8 71.0
# 112
# 56 56
# 3080 3136
# [[ 78.4  66.2]
#  [ 80.8  65. ]]
# 20.3764352138
# 114.7 88.5
# 113.4 88.2
# 104
# 52 52
# 2652 2704
# [[ 113.7   86.5]
#  [ 112.4   86.2]]
# -37.1847064532
# 87.5 63.5
# 86.0 66.6
# 94
# 47 47
# 2162 2209
# [[ 91.5  66.5]
#  [ 90.   69.6]]
# -113.782030423
# 91.3 72.4
# 95.8 70.8
# 128
# 64 64
# 4032 4096
# [[ 78.3  58.4]
#  [ 82.8  56.8]]
# 22.619864948
# 102.5 71.5
# 105.8 69.8
# 114
# 57 57
# 3192 3249
# [[ 96.5  64.5]
#  [ 99.8  62.8]]
# 34.548367056
# 77.1 69.9
# 78.8 67.5
# 88
# 44 44
# 1892 1936
# [[ 84.1  75.9]
#  [ 85.8  73.5]]
# 32.938690543
# 100.7 50.7
# 95.8 53.0
# 118
# 59 59
# 3422 3481
# [[ 92.7  41.7]
#  [ 87.8  44. ]]
# -124.249033007
# 113.8 93.3
# 117.5 92.8
# 90
# 45 45
# 1980 2025
# [[ 119.8   98.3]
#  [ 123.5   97.8]]
# 3.65222278031
# 101.5 65.8
# 102.8 62.6
# 114
# 57 57
# 3192 3249
# [[ 95.5  58.8]
#  [ 96.8  55.6]]
# 32.2756443146
# 78.5 69.5
# 79.8 68.6
# 76
# 38 38
# 1406 1444
# [[ 91.5  81.5]
#  [ 92.8  80.6]]
# 47.489552922
# 90.9 62.1
# 90.9 65.3
# 76
# 38 38
# 1406 1444
# [[ 103.9   74.1]
#  [ 103.9   77.3]]
# -136.735704589
# 107.8 74.3
# 110.5 72.5
# 94
# 47 47
# 2162 2209
# [[ 111.8   77.3]
#  [ 114.5   75.5]]
# 0.881403996582
# 87.0 73.9
# 89.0 71.7
# 84
# 42 42
# 1722 1764
# [[ 96.   81.9]
#  [ 98.   79.7]]
# 17.1027289691
# 108.4 51.0
# 107.8 53.0
# 88
# 44 44
# 1892 1936
# [[ 115.4   57. ]
#  [ 114.8   59. ]]
# 37.0730733173
# 101.2 66.2
# 103.6 65.7
# 44
# 22 22
# 462 484
# [[ 130.2   94.2]
#  [ 132.6   93.7]]
# 31.9081069357
# 105.7 64.3
# 108.8 63.5
# 112
# 56 56
# 3080 3136
# [[ 100.7   58.3]
#  [ 103.8   57.5]]
# 21.4477363271
# 60.0 70.6
# 60.0 69.0
# 58
# 29 29
# 812 841
# [[ 82.   91.6]
#  [ 82.   90. ]]
# 38.7741709356
# 109.9 83.3
# 112.3 82.3
# 46
# 23 23
# 506 529
# [[ 137.9  110.3]
#  [ 140.3  109.3]]
# 11.768288932
# 112.0 91.5
# 111.8 91.0
# 94
# 47 47
# 2162 2209
# [[ 116.    94.5]
#  [ 115.8   94. ]]
# 17.7446716251
# 100.3 65.5
# 103.0 63.8
# 98
# 49 49
# 2352 2401
# [[ 102.3   66.5]
#  [ 105.    64.8]]
# 22.1094483438
# 82.5 65.2
# 80.4 67.1
# 78
# 39 39
# 1482 1521
# [[ 94.5  76.2]
#  [ 92.4  78.1]]
# -130.100907546
# 105.0 85.7
# 110.0 86.8
# 84
# 42 42
# 1722 1764
# [[ 114.    93.7]
#  [ 119.    94.8]]
# 4.96974072811
# 78.2 72.7
# 85.2 71.8
# 144
# 72 72
# 5112 5184
# [[ 57.2  50.7]
#  [ 64.2  49.8]]
# 4.96974072811
# 90.5 61.0
# 88.5 63.5
# 94
# 47 47
# 2162 2209
# [[ 94.5  64. ]
#  [ 92.5  66.5]]
# -91.2188752351
# 86.0 65.0
# 87.3 70.8
# 120
# 60 60
# 3540 3600
# [[ 77.   55. ]
#  [ 78.3  60.8]]
# -96.5819446552
# 105.0 63.0
# 104.9 61.6
# 88
# 44 44
# 1892 1936
# [[ 112.    69. ]
#  [ 111.9   67.6]]
# 38.9909940425
# 68.6 70.4
# 70.3 68.3
# 58
# 29 29
# 812 841
# [[ 90.6  91.4]
#  [ 92.3  89.3]]
# 39.2373671134
# 105.0 66.2
# 106.3 64.3
# 104
# 52 52
# 2652 2704
# [[ 104.    64.2]
#  [ 105.3   62.3]]
# 19.1790080258
# 91.1 56.7
# 90.8 57.2
# 70
# 35 35
# 1190 1225
# [[ 107.1   71.7]
#  [ 106.8   72.2]]
# -8.74616226256
# 108.3 72.0
# 113.6 71.4
# 80
# 40 40
# 1560 1600
# [[ 119.3   82. ]
#  [ 124.6   81.4]]
# -0.0
# 93.6 104.8
# 97.2 106.8
# 70
# 35 35
# 1190 1225
# [[ 109.6  119.8]
#  [ 113.2  121.8]]
# 31.7014296695
# 86.0 56.4
# 90.8 57.2
# 228
# 114 114
# 12882 12996
# [[ 23.   -7.6]
#  [ 27.8  -6.8]]
# -0.954841253872
# 106.4 86.4
# 110.0 86.8
# 86
# 43 43
# 1806 1849
# [[ 114.4   93.4]
#  [ 118.    93.8]]
# 5.61758059013
# 89.3 61.4
# 92.0 59.5
# 122
# 61 61
# 3660 3721
# [[ 79.3  50.4]
#  [ 82.   48.5]]
# 46.7013546053

# %%
print(ct, cf)
# Out:
# 88 12

# %%
for idx, i in enumerate(error):
    if i > 180:
        error[idx] = i - 360
    
    if i < -180:
        error[idx] = i + 360
        
    if error[idx] > 90:
        error[idx] -= 180
        
    if error[idx] < -90:
        error[idx] += 180

# %%
import seaborn as sns

# %%
plt.figure() 
sns.distplot(error, rug=True)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
print(np.mean(error))
print(np.std(error))
# Out:
# -3.59004416123
# 7.597212169
