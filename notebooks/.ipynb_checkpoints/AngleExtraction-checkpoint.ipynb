# %%
# %matplotlib notebook

import numpy as np
import cv2
import os
import sys

sys.path.append('../functions/')
sys.path.append('../utils/')

from DoG import DoG
from file_manager import File_manager
from wdd_decoder_functions import create_diff_images, calculate_image_sum_for_frame, calculate_image_sum_for_angle


from matplotlib import pyplot as plt
from joblib import Parallel, delayed
from sklearn.linear_model import TheilSenRegressor
from skimage.transform import radon, rescale

from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import multivariate_normal

# %%
test = np.zeros(shape=(50, 50))

test_cov = 30 * np.eye(2)
test_cov[1][1] = test_cov[1][1] * 2

print(test_cov)

for x in range(50):
    for y in range(50):
        test[y,x] = multivariate_normal.pdf([x, y], mean=(25, 25), cov=test_cov)
        
print(test)
# Out:
# [[ 30.   0.]
#  [  0.  60.]]
# [[  6.14232228e-10   1.38997320e-09   3.04231214e-09 ...,   6.44057485e-09
#     3.04231214e-09   1.38997320e-09]
#  [  9.23994769e-10   2.09094852e-09   4.57657605e-09 ...,   9.68861158e-09
#     4.57657605e-09   2.09094852e-09]
#  [  1.36699896e-09   3.09344224e-09   6.77079018e-09 ...,   1.43337629e-08
#     6.77079018e-09   3.09344224e-09]
#  ...,
#  [  1.98897175e-09   4.50093190e-09   9.85144159e-09 ...,   2.08555020e-08
#     9.85144159e-09   4.50093190e-09]
#  [  1.36699896e-09   3.09344224e-09   6.77079018e-09 ...,   1.43337629e-08
#     6.77079018e-09   3.09344224e-09]
#  [  9.23994769e-10   2.09094852e-09   4.57657605e-09 ...,   9.68861158e-09
#     4.57657605e-09   2.09094852e-09]]

# %%
plt.figure()
plt.imshow(test)
plt.show
# Out:
# <img src="data:image/png;base64,...">
# <function matplotlib.pyplot.show>

# %%
moment = cv2.moments(test)
print(moment['m20'])
img_cov = np.array([[moment['m20'] / moment['m00'], moment['m11']], [moment['m11'], moment['m02']]])
print(img_cov)
# Out:
# 654.1596041870016
# [[ 654.9938443   624.02650055]
#  [ 624.02650055  682.9213548 ]]

# %%
circle = np.zeros(shape=(50,50))
xx, yy = np.mgrid[:50, :50]

circle = (xx - 25) ** 2 + (yy - 25) ** 2
print()
donut = np.logical_and(circle < (8**2 + 6), circle >= (0))
print(donut)
plt.figure()
plt.imshow(donut,cmap=plt.cm.gray)
plt.show
# Out:
# [[False False False ..., False False False]
#  [False False False ..., False False False]
#  [False False False ..., False False False]
#  ...,
#  [False False False ..., False False False]
#  [False False False ..., False False False]
#  [False False False ..., False False False]]
# <img src="data:image/png;base64,...">
# <function matplotlib.pyplot.show>

# %%
# %load_ext line_profiler

# %%
angles = np.arange(0, 360, 1)

angles.sort()

maxima = []
mean_val = []

cov_matrix = np.matrix([[6., 0],[0, 2.]])

smothing = np.matrix([[1,1,1],[1,1,1],[1,1,1]]) / 9

path = '/home/sascwitt/Projects/test/WDs/'
folders = os.listdir(path)
folders.sort()

# %%
dog = DoG().mexican_head_kernel

cov1 = 30 * np.eye(2)
cov2 = 4 * np.eye(2)

_dog = abs(np.fft.fftshift(np.fft.fft2(dog(50, [25,25], cov1, [25,25], cov2))))

# %%
fm_csv = File_manager("/home/sascwitt/Projects/test/WDs/").read_csv

# %%
diff_img = create_diff_images(path, folders)

# %%
fft_imgs = []
keys = []

for key, img_arrays in list(diff_img.items()):
    keys.append(key)
    image = None
    
    for img in img_arrays:
        tmp = np.fft.fftshift(abs(np.fft.fft2(img)))
        if image is None:
            image = tmp
        
        else:
            image += tmp
    
    fft_imgs.append(image)

# %%
print(keys[6])
plt.figure()
plt.imshow(fft_imgs[6])
plt.show()
# Out:
# /home/sascwitt/Projects/test/WDs/20160814_1016_1/0/
# <img src="data:image/png;base64,...">

# %%
def img_moments(image, p, q):
    height, width = image.shape
    center_x = width / 2
    center_y = height / 2
    
    x = np.arange(0, width)
    y = np.arange(0, height)

    X = np.power((x - center_x), p)[np.newaxis]
    Y = np.power((y - center_y), q)[np.newaxis]
    
    t1 = X * Y.T
    
    return sum(sum(np.multiply(t1, image)))

# %%
def get_img_cov(image):
    m00 = img_moments(image, 0, 0)
    m11_ = img_moments(image, 1, 1) / m00
    m02_ = img_moments(image, 0, 2) / m00
    m20_ = img_moments(image, 2, 0) / m00
    
    img_cov = np.array([[m20_, m11_], [m11_,m02_]])

    #w,v = np.linalg.eig(img_cov)

    return img_cov

# %%
# Out:
# [[ 29.   0.]
#  [  0.  59.]]

# %%
error = []

for index, image in enumerate(fft_imgs):
    dog_filtered = np.multiply(image, _dog)
    
    powered_dog = np.power(dog_filtered, 5)
    
    img_cov = get_img_cov(powered_dog)
    
    w, v = np.linalg.eig(img_cov)
    
    calc_angle = np.arctan2(v[1][1], v[0][1]) * 180 / np.pi
    
    
    gt_angle = float(fm_csv(keys[index] + "result.csv")["Angle"])
    
    print(calc_angle, gt_angle)
    print()
    error.append(calc_angle - gt_angle)
# Out:
# -110.585228832 22.2490236572
#
# -130.641143595 38.9909940425
#
# -129.357785039 44.3969088056
#
# -113.616936396 20.6589100633
#
# -119.931904341 31.9081069357
#
# -133.581704852 -133.958373324
#
# -72.8844742249 -6.22582906443
#
# -104.463901106 13.4310288707
#
# -120.050032066 31.5042667192
#
# 121.942560511 -121.429565615
#
# -99.3938149305 6.24191434742
#
# 122.400612144 -113.198590514
#
# -100.617052348 18.7413404452
#
# -65.2561876615 -37.1847064532
#
# 128.196593025 -130.100907546
#
# -102.150431858 16.5348378573
#
# -114.472345962 22.619864948
#
# 115.949810865 -113.782030423
#
# -91.9782419558 4.96974072811
#
# -120.533857653 21.3368592918
#
# -85.1361541535 -0.0
#
# -89.8384879134 20.2248594312
#
# -104.323215867 17.1027289691
#
# -100.69230892 11.768288932
#
# -108.670069076 19.1790080258
#
# -103.814333764 17.5712587783
#
# -129.539900279 26.2413496522
#
# -88.0868134823 -0.954841253872
#
# -83.9834832407 17.7446716251
#
# -102.882160035 20.6589100633
#
# -107.582324485 16.2940474566
#
# -79.4755468979 3.65222278031
#
# -101.064024322 17.1027289691
#
# -107.976143857 25.0168934781
#
# -91.7858149779 -0.0
#
# -112.723432093 -156.124719146
#
# 96.6825425364 -94.08561678
#
# -107.446277197 21.4477363271
#
# 111.57172166 -113.198590514
#
# 95.9455063775 -91.2188752351
#
# -128.375789263 34.548367056
#
# -114.140612986 32.938690543
#
# -102.882160035 20.3764352138
#
# -72.1945205141 -9.09027692082
#
# 132.746546675 41.3915311474
#
# 132.672565892 -127.694240467
#
# -118.469475037 38.7741709356
#
# -63.466831692 -18.6989828042
#
# -85.67247609 -1.81830296445
#
# -82.4936043901 9.03948280336
#
# -105.752103674 18.7586503478
#
# 89.6726977129 -94.2363947991
#
# -133.456985978 39.2373671134
#
# -84.3793970617 4.96974072811
#
# -79.8779654629 -8.74616226256
#
# -124.358187055 -126.027373385
#
# 80.0307706735 -56.5921754103
#
# -127.780390022 -134.492970939
#
# -111.342572011 22.1094483438
#
# -118.775955546 32.2756443146
#
# -115.379629433 13.799485396
#
# -89.1097884487 0.881403996582
#
# -133.88796743 -126.027373385
#
# -116.523659822 13.0693178963
#
# -106.52813767 31.7014296695
#
# -119.666140183 47.489552922
#
# -85.7916243533 -0.0
#
# 123.454290129 -118.300755766
#
# -133.96171171 -136.735704589
#
# -54.0422258985 -34.6951535312
#
# -129.431556906 -147.587693382
#
# -108.169633548 24.5671713206
#
# -111.802042786 14.5344550805
#
# -96.5804362775 9.16234704572
#
# -106.970568696 16.9275130641
#
# 119.425750341 -120.963756532
#
# -122.463072463 -146.611486424
#
# -91.476017993 5.61758059013
#
# -83.4762093797 -0.84252426074
#
# -89.6119652497 2.72631099391
#
# -113.34871071 32.5350671579
#
# -120.421104238 21.4767909795
#
# -112.049178833 33.690067526
#
# -129.33477765 -129.805571092
#
# -124.944736584 46.7013546053
#
# 128.426677154 -134.215175397
#
# -102.848451744 33.9435870198
#
# -94.0332807891 14.9950791292
#
# -104.03660756 13.2405199152
#
# 114.407020877 -109.384515679
#
# -128.675250749 -146.023455964
#
# -132.105428112 42.8789036033
#
# -104.318668367 13.4957332808
#
# -120.008388854 30.3236068625
#
# 101.552189258 -96.5819446552
#
# -132.313449894 -124.249033007
#
# -113.326217058 17.4747742563
#
# 99.4297607548 -93.6329507395
#
# -81.0480729841 -2.81555668421
#
# -112.844906352 37.0730733173

# %%
for idx, i in enumerate(error):
    if i > 180:
        error[idx] = i - 360
    
    if i < -180:
        error[idx] = i + 360
        
    if error[idx] > 90:
        error[idx] -= 180
        
    if error[idx] < -90:
        error[idx] += 180

# %%
print(fft_imgs[1].shape)
plt.figure() 
plt.hist(error, bins=100)
plt.show()
# Out:
# (50, 50)
# <img src="data:image/png;base64,...">

# %%
# Out:
# (1, 50)
# (50, 50)
# (1, 50)
# (50, 50)
# (1, 50)
# (50, 50)
# (1, 50)
# (50, 50)
# [[  2.99965693e+01   3.84384718e-07]
#  [  3.84384718e-07   5.91449254e+01]]
